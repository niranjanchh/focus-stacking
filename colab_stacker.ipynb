# %% [markdown]
# # Focus Stacking - Google Colab Environment
# This notebook allows you to run your Focus Stacking pipeline entirely in the cloud using Google's servers.
# Ensure that this notebook, your python files (`alignment.py`, `stacking.py`, `gui.py`, `run_stack.py`), and your images are all located in the same folder in your Google Drive.

# %% [markdown]
# ### 1. Mount Google Drive
# This gives Colab access to read your code/images and write the final blended TIFF back to your Drive.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### 2. Install Dependencies
# Installs OpenCV, Numpy, and Pillow. We use `opencv-python-headless` so it doesn't crash trying to load GUI tools on a cloud server.

# %%
# !pip install opencv-python-headless numpy Pillow

# %% [markdown]
# ### 3. Run the Stacker
# This runs the stacking script directly on your specific Google Drive folder.

# %%
import os

# PATH TO YOUR FOLDER:
DRIVE_FOLDER_PATH = "/content/drive/MyDrive/Colab Notebooks/Bilinear_TIF"

# Change directory so the script can find its own imports
os.chdir(DRIVE_FOLDER_PATH)

# Run the stacker
# !python run_stack.py . --method pyramid --energy 1.0 --deghost
